# %%
import json
import os
import platform
import sys
from pathlib import Path

# %%
'''
ENVIRONMENT VARIABLES
'''
SYSTEM = platform.system()
HOME = Path.home()
RESOURCES_DIR = HOME / "resources"
NATURAL_DATA_DIR = RESOURCES_DIR / "natural_data"
PERIODIC_TABLE_DATA_PATH = NATURAL_DATA_DIR / "POtE.json"

# Outputting data to console
print(f"\nOS: {SYSTEM}\n")
# Out:
# OS: Windows

# %%
print(
    "THE PERIODIC TABLE OF ELEMENTS",
    "\n" * 2
)
with open(PERIODIC_TABLE_DATA_PATH, "r") as f:
    data = json.load(f)
    table = data["elements"]
    info = tuple(table)
for i in range(len(info)):
    attribute = info[i]
    print(f"[{i+1}]")
    for j in attribute:
        state = attribute[j]
        print(f"{j}: {state}")
    print("\n" + "----" + "\n")

class Element:
    def __init(self, name, symbol, atomic_number, atomic_mass, category):
        self.name = name.str()
        self.symbol = symbol.str()
        self.atomic_number = atomic_number.int()
        self.atomic_mass = atomic_mass.float()
        self.category = category.str()
        self.data = json.load(f) with open(PERIODIC_TABLE_DATA_PATH, r) as f

    def name_to_num(self):
        self.atomic_number = self.data["elements"][
# Out:
# THE PERIODIC TABLE OF ELEMENTS
#
#
# [1]
# name: Hydrogen
# symbol: H
# atomic_number: 1
# atomic_mass: 1.008
# category: Nonmetal
#
# ----
#
# [2]
# name: Helium
# symbol: He
# atomic_number: 2
# atomic_mass: 4.0026
# category: Noble Gas
#
# ----
#
# [3]
# name: Lithium
# symbol: Li
# atomic_number: 3
# atomic_mass: 6.94
# category: Alkali Metal
#
# ----
#
# [4]
# name: Beryllium
# symbol: Be
# atomic_number: 4
# atomic_mass: 9.0122
# category: Alkaline Earth Metal
#
# ----
#
# [5]
# name: Boron
# symbol: B
# atomic_number: 5
# atomic_mass: 10.81
# category: Metalloid
#
# ----
#
# [6]
# name: Carbon
# symbol: C
# atomic_number: 6
# atomic_mass: 12.011
# category: Nonmetal
#
# ----
#
# [7]
# name: Nitrogen
# symbol: N
# atomic_number: 7
# atomic_mass: 14.007
# category: Nonmetal
#
# ----
#
# [8]
# name: Oxygen
# symbol: O
# atomic_number: 8
# atomic_mass: 15.999
# category: Nonmetal
#
# ----
#
# [9]
# name: Fluorine
# symbol: F
# atomic_number: 9
# atomic_mass: 18.998
# ...
